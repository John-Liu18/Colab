# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Liu18/Colab/blob/main/5_29_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# doc: https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

#讀取文本
file_text = open('/content/drive/MyDrive/FJU/文本/Evenings with idries Shah.txt','r').read()


# background_color 背景顏色
# width 寬
# height 高
# margin 圖片邊緣
# max_font_size 設定文字中最大的大小是多少
# min_font_size
# max_words  文字雲顯示最大詞數
# font_path="/tmp/DFFT_C7.ttc", #設置字體

temp = WordCloud(
    background_color="white",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)


plt.imshow(temp)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dc08c45283ce> in <cell line: 0>()
#       5
#       6 #讀取文本
# ----> 7 file_text = open('/content/drive/MyDrive/FJU/文本/Evenings with idries Shah.txt','r').read()
#       8
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/FJU/文本/Evenings with idries Shah.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/MyDrive/FJU/文本"
# Out:
# 'Evenings with idries Shah.txt'   Kara_Kush.txt  'The Wat of the Sufi.txt'

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader

#PlaintextCorpusReader
#讀取純文字檔案，並把它們當作語料庫（corpus）來分析
corpus_root = '/content/drive/MyDrive/FJU/文本' # 請改成自己的路徑 File Path
wordlists = PlaintextCorpusReader(corpus_root, '.*') # .* => find all files, .txt => only find txt files

books = wordlists.fileids() # 回傳檔名
print(books)
# Out:
# ['Evenings with idries Shah.txt', 'Kara_Kush.txt', 'The Wat of the Sufi.txt']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# doc: https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

#讀取文本
file_text = open('/content/drive/MyDrive/FJU/文本/Evenings with idries Shah.txt','r').read()


# background_color 背景顏色
# width 寬
# height 高
# margin 圖片邊緣
# max_font_size 設定文字中最大的大小是多少
# min_font_size
# max_words  文字雲顯示最大詞數
# font_path="/tmp/DFFT_C7.ttc", #設置字體

temp = WordCloud(
    background_color="white",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)


plt.imshow(temp)
plt.axis("off")
plt.show()

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'into', 'could', 'itself', "i'm", 'some', 'that', 'who', 'being', 'herself', 'ours', 'which', 'otherwise', 'very', 'again', 'during', 'your', 'against', 'only', 'at', 'through', "mustn't", 'r', 'com', 'same', 'our', 'get', 'cannot', 'an', 'also', 'but', "that's", 'www', 'me', "he'd", 'how', 'if', 'is', 'out', 'such', 'however', 'was', "when's", 'so', 'too', 'as', 'not', "they've", 'this', "he's", "can't", 'here', 'more', 'then', 'those', 'has', 'since', 'between', 'any', 'down', 'while', 'like', 'are', 'on', "hadn't", "here's", 'for', 'he', "weren't", "shouldn't", "wouldn't", 'all', "we're", 'off', 'do', 'over', 'does', "doesn't", 'am', 'it', 'where', 'of', "they'll", "you'll", 'there', "what's", 'their', "who's", 'until', 'most', 'ought', 'before', 'no', "i'll", 'under', "shan't", 'themselves', 'above', 'own', "we'd", 'did', 'few', 'my', "i'd", "couldn't", 'been', 'or', "she's", 'what', 'be', 'below', 'his', 'once', 'hence', 'both', "won't", "wasn't", 'ourselves', 'and', "don't", '
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本/Evenings with idries Shah.txt','r').read()

# stopwords 停用字詞
stop = ["people", "old people", "time", "life"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞
