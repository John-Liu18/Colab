# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Liu18/Colab/blob/main/Final_Project_Group1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/MyDrive/FJU/文本3"
# Out:
# 柯南道爾-man.txt    道格-man.txt    阿嘉莎-man.txt
# 柯南道爾-woman.txt  道格-woman.txt  阿嘉莎-woman.txt

# %%
import nltk
nltk.download("popular")
nltk.download('all-corpora')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader

#PlaintextCorpusReader
#讀取純文字檔案，並把它們當作語料庫（corpus）來分析
corpus_root = '/content/drive/MyDrive/FJU/文本3' # 請改成自己的路徑 File Path
wordlists = PlaintextCorpusReader(corpus_root, '.*') # .* => find all files, .txt => only find txt files

books = wordlists.fileids() # 回傳檔名
print(books)
# Out:
# ['柯南道爾-man.txt', '柯南道爾-woman.txt', '道格-man.txt', '道格-woman.txt', '阿嘉莎-man.txt', '阿嘉莎-woman.txt']

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('柯南道爾-man.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('young', 13), ('said', 9), ('old', 7), ('like', 6), ('holmes', 5), ('little', 5), ('mccarthy', 5), ('could', 5), ('day', 4), ('upon', 4), ('point', 4), ('must', 4), ('hand', 4), ('would', 4), ('however', 4), ('see', 4), ('dead', 4), ('study', 3), ('one', 3), ('know', 3)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/柯南道爾-man.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S","D","Holmes"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('柯南道爾-woman.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('woman', 9), ('old', 2), ('cried', 2), ('osely', 1), ('followed', 1), ('slipshod', 1), ('elderly', 1), ('another', 1), ('occasion', 1), ('white', 1), ('mystified', 1), ('eye', 1), ('wedding', 1), ('ring', 1), ('held', 1), ('cleared', 1), ('find', 1), ('named', 1), ('rachel', 1), ('something', 1)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/柯南道爾-woman.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S","olsely"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('道格-man.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in "—" and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('white', 36), ('old', 26), ('mr', 24), ('slave', 23), ('every', 21), ('colored', 20), ('covey', 19), ('good', 17), ('could', 17), ('one', 16), ('poor', 14), ('would', 14), ('young', 13), ('master', 11), ('day', 10), ('said', 9), ('black', 8), ('named', 8), ('must', 8), ('slavery', 8)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/道格-man.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S","t","b"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('道格-woman.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in "woman" and token not in "—" and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('slave', 10), ('young', 9), ('old', 4), ('seen', 4), ('hearted', 4), ('mr', 4), ('whose', 4), ('whip', 3), ('kind', 3), ('tender', 3), ('tie', 3), ('caroline', 3), ('covey', 3), ('name', 3), ('one', 3), ('master', 3), ('son', 3), ('left', 2), ('heart', 2), ('ever', 2)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/道格-woman.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('阿嘉莎-man.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in '.’' and token not in '‘' and token not in "woman" and token not in "—" and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('young', 123), ('said', 71), ('one', 60), ('like', 41), ('poirot', 38), ('old', 37), (".'", 34), ('mr', 33), ('would', 32), ('know', 32), ('."', 32), ('yes', 30), ('well', 26), ('think', 25), ('looking', 25), ('little', 24), ('came', 24), ('good', 24), ('?"', 23), ('?’', 22)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/阿嘉莎-man.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S","Ye","t","e","re","Poirot","d"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
import string

dataset = wordlists.raw('阿嘉莎-woman.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')


wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = [token for token in text_list if token.lower() not in stop]

# 去掉標點 and empty strings
no_string_tokens = [token for token in clean_tokens if token not in string.punctuation and token not in '.’' and token not in '‘' and token not in "woman" and token not in "—" and token not in '--' and token not in '?' and token not in '!' and token != '' and token not in '"'and token not in '?”' and token not in 'man' and token not in '“'and token not in '’'and token not in '’'and token not in '.”'and token not in ',”'and token not in 'e']


# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的20個單字
fdist1 = fdist.most_common(20)
print(fdist1)
# Out:
# [('young', 44), ('said', 41), ('mr', 26), ('old', 25), ('like', 25), ('know', 20), ('."', 20), ('looking', 18), ('dead', 17), ('could', 16), ('would', 16), ('one', 16), ('good', 15), ('?"', 15), (".'", 15), (',"', 14), ('face', 12), ('looked', 12), ('miss', 12), ('think', 11)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/FJU/文本3/阿嘉莎-woman.txt','r').read()

# stopwords 停用字詞
stop = ["man","woman","S","d","Poirot","th"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞
